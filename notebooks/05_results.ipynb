# %% [markdown]
# # Results and figures
#
# Pull every saved result together and regenerate the figures and paper tables.
# Nothing here recomputes anything; it reads results/ so that the notebook and the manuscript cannot disagree.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

# %%
import pandas as pd
from src import config as cfg, visualization as viz, report

# %%
_, res = cfg.output_dirs()
sorted(p.name for p in res.glob('*.csv'))

# %%
pd.read_csv(res / 'robustness.csv')[['analysis','setting','roc_auc']]

# %%
viz.main()

# %%
print(report.build()[:3000])
