# %% [markdown]
# # Data exploration
#
# Inspect what was actually downloaded before trusting any of it: channel counts, sampling rate, durations, and whether the checksums verified.
# Any surprise here is cheaper to find now than after a full pipeline run.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

# %%
from src import config as cfg, preprocessing as pp

# %%
prov = cfg.read_provenance(); prov

# %%
subjects = pp.available_subjects(); print(len(subjects), 'participants with both runs')

# %%
import mne
raw = mne.io.read_raw_edf(cfg.RAW / subjects[0] / f'{subjects[0]}R01.edf', preload=True, verbose='error')
print(raw.info)
print('duration', raw.n_times / raw.info['sfreq'], 's')

# %%
raw.plot_psd(fmax=60);
