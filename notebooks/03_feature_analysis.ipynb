# %% [markdown]
# # Feature and frequency analysis
#
# Build the 674-feature matrix and check the confirmatory result: does occipital relative alpha actually rise on eye closure?
# If it does not, the whole cost analysis downstream is meaningless.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

# %%
import pandas as pd
from src import config as cfg, statistics as st

# %%
features = pd.read_csv(cfg.FEATURES_CSV)
features.shape

# %%
st.occipital_alpha_summary(features)

# %%
bands = st.global_band_table(features)
bands[['band','rel_dz','abs_dz','abs_fold_change','interpretation']]

# %%
# Relative power is compositional. The 'interpretation' column above is what
# separates a genuine spectral change from a renormalisation artifact.
tab = st.channel_band_table(features, 'logabs')
tab.head(10)
