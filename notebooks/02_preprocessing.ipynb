# %% [markdown]
# # Preprocessing
#
# Run one recording through the pipeline and look at what each step changed.
# The bad-channel rule is the one worth watching: a variance-only criterion flags every frontal electrode, because frontal channels legitimately carry ocular variance.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

# %%
from src import config as cfg, preprocessing as pp

# %%
epochs, qc = pp.process_recording('S001', 'R02')
qc.as_row()

# %%
print('bad channels:', qc.bad_channels)
print('epochs kept:', qc.n_epochs_kept, 'of', qc.n_epochs_total)

# %%
epochs.average().plot(spatial_colors=True);
